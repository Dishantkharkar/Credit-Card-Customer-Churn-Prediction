# %% [markdown]
# <a href="https://www.kaggle.com/code/dishantkharkar/credit-card-customer-churn-prediction-ann?scriptVersionId=157632459" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/credit-card-customer-churn-prediction/Churn_Modelling.csv

# %% [markdown]
# # Import Dataset

# %%
df  = pd.read_csv('/kaggle/input/credit-card-customer-churn-prediction/Churn_Modelling.csv')

df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %% [markdown]
# # Data Preprocessing

# %%
df.drop(columns=['RowNumber','CustomerId','Surname'],inplace=True)

# %%
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
df['Geography'].value_counts()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      5457
# Female    4543
# Name: count, dtype: int64

# %%
df = pd.get_dummies(df,columns=['Geography','Gender'],drop_first=True)

df.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 0               1        101348.88       1              False
# 1               1        112542.58       0              False
# 2               0        113931.57       1              False
# 3               0         93826.63       0              False
# 4               1         79084.10       0              False
#
#    Geography_Spain  Gender_Male
# 0            False        False
# 1             True        False
# 2            False        False
# 3            False        False
# 4             True        False

# %% [markdown]
# # Split Data Into X and y

# %%
X = df.drop(columns=['Exited'])
y = df['Exited'].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_trf = scaler.fit_transform(X_train)
X_test_trf = scaler.fit_transform(X_test)

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(11,activation='sigmoid',input_dim=11))
model.add(Dense(11,activation='sigmoid'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 11)                132
#
#  dense_1 (Dense)             (None, 11)                132
#
#  dense_2 (Dense)             (None, 1)                 12
#
# =================================================================
# Total params: 276 (1.08 KB)
# Trainable params: 276 (1.08 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(X_train_trf,y_train,batch_size=50,epochs=100,verbose=1,validation_split=0.2)
# Out:
# Epoch 1/100
# 128/128 [==============================] - 1s 3ms/step - loss: 0.5035 - accuracy: 0.7958 - val_loss: 0.4905 - val_accuracy: 0.7969
# Epoch 2/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4834 - accuracy: 0.7958 - val_loss: 0.4755 - val_accuracy: 0.7969
# Epoch 3/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4657 - accuracy: 0.7958 - val_loss: 0.4584 - val_accuracy: 0.7969
# Epoch 4/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4489 - accuracy: 0.7958 - val_loss: 0.4453 - val_accuracy: 0.7969
# Epoch 5/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4372 - accuracy: 0.7991 - val_loss: 0.4376 - val_accuracy: 0.8012
# Epoch 6/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4305 - accuracy: 0.8062 - val_loss: 0.4341 - val_accuracy: 0.8100
# Epoch 7/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4271 - accuracy: 0.8097 - val_loss: 0.4318 - val_accuracy: 0.8138
# Epoch 8/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4248 - accuracy: 0.8131 - val_loss: 0.4305 - val_accuracy: 0.8087
# Epoch 9/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4233 - accuracy: 0.8133 - val_loss: 0.4293 - val_accuracy: 0.8094
# Epoch 10/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4220 - accuracy: 0.8142 - val_loss: 0.4279 - val_accuracy: 0.8125
# Epoch 11/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4207 - accuracy: 0.8138 - val_loss: 0.4265 - val_accuracy: 0.8125
# Epoch 12/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4192 - accuracy: 0.8161 - val_loss: 0.4249 - val_accuracy: 0.8138
# Epoch 13/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4176 - accuracy: 0.8169 - val_loss: 0.4233 - val_accuracy: 0.8156
# Epoch 14/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4156 - accuracy: 0.8184 - val_loss: 0.4215 - val_accuracy: 0.8163
# Epoch 15/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4143 - accuracy: 0.8205 - val_loss: 0.4190 - val_accuracy: 0.8194
# Epoch 16/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4121 - accuracy: 0.8228 - val_loss: 0.4171 - val_accuracy: 0.8225
# Epoch 17/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.4100 - accuracy: 0.8242 - val_loss: 0.4155 - val_accuracy: 0.8256
# Epoch 18/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4084 - accuracy: 0.8267 - val_loss: 0.4131 - val_accuracy: 0.8288
# Epoch 19/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4063 - accuracy: 0.8294 - val_loss: 0.4110 - val_accuracy: 0.8325
# Epoch 20/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4044 - accuracy: 0.8313 - val_loss: 0.4090 - val_accuracy: 0.8313
# Epoch 21/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4024 - accuracy: 0.8317 - val_loss: 0.4070 - val_accuracy: 0.8338
# Epoch 22/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4005 - accuracy: 0.8328 - val_loss: 0.4054 - val_accuracy: 0.8350
# Epoch 23/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3986 - accuracy: 0.8339 - val_loss: 0.4034 - val_accuracy: 0.8375
# Epoch 24/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3966 - accuracy: 0.8373 - val_loss: 0.4022 - val_accuracy: 0.8313
# Epoch 25/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3950 - accuracy: 0.8359 - val_loss: 0.3997 - val_accuracy: 0.8319
# Epoch 26/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3932 - accuracy: 0.8377 - val_loss: 0.3980 - val_accuracy: 0.8344
# Epoch 27/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3912 - accuracy: 0.8384 - val_loss: 0.3961 - val_accuracy: 0.8388
# Epoch 28/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3892 - accuracy: 0.8383 - val_loss: 0.3945 - val_accuracy: 0.8363
# Epoch 29/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3875 - accuracy: 0.8411 - val_loss: 0.3929 - val_accuracy: 0.8406
# Epoch 30/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3858 - accuracy: 0.8411 - val_loss: 0.3915 - val_accuracy: 0.8369
# Epoch 31/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3842 - accuracy: 0.8419 - val_loss: 0.3898 - val_accuracy: 0.8400
# Epoch 32/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3824 - accuracy: 0.8428 - val_loss: 0.3882 - val_accuracy: 0.8400
# Epoch 33/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3806 - accuracy: 0.8423 - val_loss: 0.3872 - val_accuracy: 0.8419
# Epoch 34/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3792 - accuracy: 0.8436 - val_loss: 0.3855 - val_accuracy: 0.8394
# Epoch 35/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3778 - accuracy: 0.8455 - val_loss: 0.3841 - val_accuracy: 0.8394
# Epoch 36/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3760 - accuracy: 0.8452 - val_loss: 0.3828 - val_accuracy: 0.8413
# Epoch 37/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3746 - accuracy: 0.8452 - val_loss: 0.3816 - val_accuracy: 0.8431
# Epoch 38/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3732 - accuracy: 0.8462 - val_loss: 0.3805 - val_accuracy: 0.8444
# Epoch 39/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3720 - accuracy: 0.8466 - val_loss: 0.3794 - val_accuracy: 0.8450
# Epoch 40/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3706 - accuracy: 0.8480 - val_loss: 0.3787 - val_accuracy: 0.8425
# Epoch 41/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3694 - accuracy: 0.8473 - val_loss: 0.3778 - val_accuracy: 0.8450
# Epoch 42/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3681 - accuracy: 0.8467 - val_loss: 0.3770 - val_accuracy: 0.8456
# Epoch 43/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3671 - accuracy: 0.8484 - val_loss: 0.3770 - val_accuracy: 0.8462
# Epoch 44/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.3659 - accuracy: 0.8480 - val_loss: 0.3750 - val_accuracy: 0.8475
# Epoch 45/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3649 - accuracy: 0.8497 - val_loss: 0.3747 - val_accuracy: 0.8469
# Epoch 46/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.3636 - accuracy: 0.8486 - val_loss: 0.3737 - val_accuracy: 0.8494
# Epoch 47/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3623 - accuracy: 0.8509 - val_loss: 0.3738 - val_accuracy: 0.8475
# Epoch 48/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3619 - accuracy: 0.8494 - val_loss: 0.3725 - val_accuracy: 0.8487
# Epoch 49/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3609 - accuracy: 0.8516 - val_loss: 0.3719 - val_accuracy: 0.8525
# Epoch 50/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3601 - accuracy: 0.8508 - val_loss: 0.3718 - val_accuracy: 0.8494
# Epoch 51/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3594 - accuracy: 0.8508 - val_loss: 0.3709 - val_accuracy: 0.8506
# Epoch 52/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3587 - accuracy: 0.8516 - val_loss: 0.3702 - val_accuracy: 0.8531
# Epoch 53/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3580 - accuracy: 0.8525 - val_loss: 0.3702 - val_accuracy: 0.8537
# Epoch 54/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.3569 - accuracy: 0.8537 - val_loss: 0.3695 - val_accuracy: 0.8537
# Epoch 55/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3565 - accuracy: 0.8545 - val_loss: 0.3696 - val_accuracy: 0.8544
# Epoch 56/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.3556 - accuracy: 0.8541 - val_loss: 0.3691 - val_accuracy: 0.8556
# Epoch 57/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3550 - accuracy: 0.8530 - val_loss: 0.3692 - val_accuracy: 0.8537
# Epoch 58/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3546 - accuracy: 0.8539 - val_loss: 0.3680 - val_accuracy: 0.8537
# Epoch 59/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3537 - accuracy: 0.8556 - val_loss: 0.3681 - val_accuracy: 0.8550
# Epoch 60/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3531 - accuracy: 0.8544 - val_loss: 0.3673 - val_accuracy: 0.8544
# Epoch 61/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3526 - accuracy: 0.8559 - val_loss: 0.3668 - val_accuracy: 0.8556
# Epoch 62/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3521 - accuracy: 0.8577 - val_loss: 0.3669 - val_accuracy: 0.8556
# Epoch 63/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3518 - accuracy: 0.8567 - val_loss: 0.3666 - val_accuracy: 0.8556
# Epoch 64/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.3515 - accuracy: 0.8587 - val_loss: 0.3682 - val_accuracy: 0.8550
# Epoch 65/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3506 - accuracy: 0.8583 - val_loss: 0.3657 - val_accuracy: 0.8525
# Epoch 66/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3502 - accuracy: 0.8592 - val_loss: 0.3655 - val_accuracy: 0.8556
# Epoch 67/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3496 - accuracy: 0.8578 - val_loss: 0.3653 - val_accuracy: 0.8569
# Epoch 68/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3492 - accuracy: 0.8586 - val_loss: 0.3648 - val_accuracy: 0.8531
# Epoch 69/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3488 - accuracy: 0.8583 - val_loss: 0.3646 - val_accuracy: 0.8531
# Epoch 70/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3485 - accuracy: 0.8602 - val_loss: 0.3644 - val_accuracy: 0.8525
# Epoch 71/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3482 - accuracy: 0.8602 - val_loss: 0.3643 - val_accuracy: 0.8562
# Epoch 72/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3474 - accuracy: 0.8592 - val_loss: 0.3650 - val_accuracy: 0.8556
# Epoch 73/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3471 - accuracy: 0.8608 - val_loss: 0.3641 - val_accuracy: 0.8544
# Epoch 74/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3467 - accuracy: 0.8587 - val_loss: 0.3644 - val_accuracy: 0.8550
# Epoch 75/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3462 - accuracy: 0.8598 - val_loss: 0.3641 - val_accuracy: 0.8544
# Epoch 76/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3460 - accuracy: 0.8611 - val_loss: 0.3648 - val_accuracy: 0.8544
# Epoch 77/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3452 - accuracy: 0.8606 - val_loss: 0.3628 - val_accuracy: 0.8537
# Epoch 78/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3450 - accuracy: 0.8605 - val_loss: 0.3628 - val_accuracy: 0.8537
# Epoch 79/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3448 - accuracy: 0.8609 - val_loss: 0.3625 - val_accuracy: 0.8537
# Epoch 80/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3444 - accuracy: 0.8606 - val_loss: 0.3625 - val_accuracy: 0.8525
# Epoch 81/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3440 - accuracy: 0.8606 - val_loss: 0.3621 - val_accuracy: 0.8550
# Epoch 82/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3436 - accuracy: 0.8617 - val_loss: 0.3620 - val_accuracy: 0.8537
# Epoch 83/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3434 - accuracy: 0.8611 - val_loss: 0.3618 - val_accuracy: 0.8519
# Epoch 84/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.3431 - accuracy: 0.8606 - val_loss: 0.3622 - val_accuracy: 0.8544
# Epoch 85/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3426 - accuracy: 0.8620 - val_loss: 0.3613 - val_accuracy: 0.8544
# Epoch 86/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3422 - accuracy: 0.8614 - val_loss: 0.3630 - val_accuracy: 0.8525
# Epoch 87/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3423 - accuracy: 0.8625 - val_loss: 0.3616 - val_accuracy: 0.8544
# Epoch 88/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3418 - accuracy: 0.8611 - val_loss: 0.3609 - val_accuracy: 0.8562
# Epoch 89/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3416 - accuracy: 0.8625 - val_loss: 0.3609 - val_accuracy: 0.8556
# Epoch 90/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3411 - accuracy: 0.8620 - val_loss: 0.3608 - val_accuracy: 0.8556
# Epoch 91/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3407 - accuracy: 0.8628 - val_loss: 0.3610 - val_accuracy: 0.8556
# Epoch 92/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3408 - accuracy: 0.8627 - val_loss: 0.3609 - val_accuracy: 0.8562
# Epoch 93/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3413 - accuracy: 0.8623 - val_loss: 0.3605 - val_accuracy: 0.8550
# Epoch 94/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3400 - accuracy: 0.8612 - val_loss: 0.3605 - val_accuracy: 0.8550
# Epoch 95/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3396 - accuracy: 0.8628 - val_loss: 0.3613 - val_accuracy: 0.8537
# Epoch 96/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3396 - accuracy: 0.8631 - val_loss: 0.3598 - val_accuracy: 0.8556
# Epoch 97/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3390 - accuracy: 0.8627 - val_loss: 0.3595 - val_accuracy: 0.8562
# Epoch 98/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3395 - accuracy: 0.8634 - val_loss: 0.3599 - val_accuracy: 0.8575
# Epoch 99/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3389 - accuracy: 0.8616 - val_loss: 0.3595 - val_accuracy: 0.8544
# Epoch 100/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3385 - accuracy: 0.8614 - val_loss: 0.3611 - val_accuracy: 0.8556

# %%
y_pred = model.predict(X_test_trf)
# Out:
# 63/63 [==============================] - 0s 1ms/step

# %%
y_pred
# Out:
# array([[0.21474497],
#        [0.25718233],
#        [0.11552445],
#        ...,
#        [0.10307396],
#        [0.08386561],
#        [0.20431782]], dtype=float32)

# %%
y_pred = y_pred.argmax(axis=-1)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.7975

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
